# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('desempleo1.csv')
print("COLUMNAS QUE HAY EN EL DOCUMENTO")
print(df.shape)
# Out:
# COLUMNAS QUE HAY EN EL DOCUMENTO
# (30646, 165)
# C:\Users\INTEL\AppData\Local\Temp\ipykernel_5524\3225731199.py:1: DtypeWarning: Columns (163) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('desempleo1.csv')

# %%
print(df.fillna(0)) #remplazamos datos nulos por 0
# Out:
#          _id  area  ciudad  conglomerado  panelm  vivienda  hogar  p01  p02  \
# 0          1     2  200250            22       5         2      1    1    2
# 1          2     2  200250            22       5         2      1    2    1
# 2          3     2  200250            22       5         3      1    1    2
# 3          4     2  200250            22       5         3      1    2    1
# 4          5     2  200250            22       5         3      1    3    2
# ...      ...   ...     ...           ...     ...       ...    ...  ...  ...
# 30641  30642     2   50150        910102       9         9      1    3    1
# 30642  30643     2   50150        910102       9         9      1    4    1
# 30643  30644     2   50150        910102       9         9      1    5    1
# 30644  30645     2   50150        910102       9         9      1    6    2
# 30645  30646     2   50150        910102       9         9      1    7    2
#
# ...

# %%
print(df.head(10))
# Out:
#    _id  area  ciudad  conglomerado  panelm  vivienda  hogar  p01  p02  p03  \
# 0    1     2  200250            22       5         2      1    1    2   55
# 1    2     2  200250            22       5         2      1    2    1   39
# 2    3     2  200250            22       5         3      1    1    2   30
# 3    4     2  200250            22       5         3      1    2    1   33
# 4    5     2  200250            22       5         3      1    3    2    0
# 5    6     2  200250            22       5         5      1    1    2   58
# 6    7     2  200250            22       5         5      1    2    1   24
# 7    8     2  200250            22       5         5      1    3    1   92
# 8    9     2  200250            22       5         6      1    1    2   32
# 9   10     2  200250            22       5         6      1    2    1   34
#
#    ...             ingpc  pobreza  epobreza nnivins estrato           upm  \
# ...

# %%
df.describe() #descripcion de los datos que tenemos
# Out:
#                 _id          area         ciudad   conglomerado        panelm  \
# count  30646.000000  30646.000000   30646.000000   30646.000000  30646.000000
# mean   15323.500000      1.367487  110462.213535  351664.304216      6.948052
# std     8846.882511      0.482128   60553.899490  393718.161046      1.999358
# min        1.000000      1.000000   10150.000000      22.000000      5.000000
# 25%     7662.250000      1.000000   70150.000000   15802.000000      5.000000
# 50%    15323.500000      1.000000   90852.000000   89052.000000      5.000000
# 75%    22984.750000      2.000000  170150.000000  900376.750000      9.000000
# max    30646.000000      2.000000  240350.000000  910102.000000      9.000000
#
#            vivienda         hogar           p01           p02           p03  \
# count  30646.000000  30646.000000  30646.000000  30646.000000  30646.000000
# mean       4.610063      1.002741      2.732755      1.509365     33.889415
# ...

# %%
df.mean(axis=0) #informa del axis que debo usar para la limpieza
# Out:
# C:\Users\INTEL\AppData\Local\Temp\ipykernel_5524\2681518468.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis=0)
# _id             1.532350e+04
# area            1.367487e+00
# ciudad          1.104622e+05
# conglomerado    3.516643e+05
# panelm          6.948052e+00
# vivienda        4.610063e+00
# hogar           1.002741e+00
# p01             2.732755e+00
# p02             1.509365e+00
# p03             3.388941e+01
# p04             2.693141e+00
# p05a            6.969523e+00
# p05b            9.949390e+00
# p15aa           1.336749e+00
# p82             7.831365e-03
# ced01a          1.034523e+00
# condact         3.856817e+00
# estrato         1.987868e+03
# upm             1.104626e+11
# id_vivienda     1.104626e+16
# id_hogar        1.104626e+17
# periodo         2.020120e+05
# ...

# %%
df.drop(columns = ["p01","p02","p04","p05a","p05b","p15aa","p82","p03","p06","p07","p08","p08a","p08b","p09","p10a","p10b"], axis = 0) 
#borramos columnas que no necesitamos
# Out:
#          _id  area  ciudad  conglomerado  panelm  vivienda  hogar p11 p12a  \
# 0          1     2  200250            22       5         2      1
# 1          2     2  200250            22       5         2      1
# 2          3     2  200250            22       5         3      1        1
# 3          4     2  200250            22       5         3      1        1
# 4          5     2  200250            22       5         3      1
# ...      ...   ...     ...           ...     ...       ...    ...  ..  ...
# 30641  30642     2   50150        910102       9         9      1
# 30642  30643     2   50150        910102       9         9      1
# 30643  30644     2   50150        910102       9         9      1   1
# 30644  30645     2   50150        910102       9         9      1   2
# 30645  30646     2   50150        910102       9         9      1
#
#            p12b  ...             ingpc pobreza epobreza nnivins estrato  \
# ...

# %%
df.head(10)
# Out:
#    _id  area  ciudad  conglomerado  panelm  vivienda  hogar  p01  p02  p03  \
# 0    1     2  200250            22       5         2      1    1    2   55
# 1    2     2  200250            22       5         2      1    2    1   39
# 2    3     2  200250            22       5         3      1    1    2   30
# 3    4     2  200250            22       5         3      1    2    1   33
# 4    5     2  200250            22       5         3      1    3    2    0
# 5    6     2  200250            22       5         5      1    1    2   58
# 6    7     2  200250            22       5         5      1    2    1   24
# 7    8     2  200250            22       5         5      1    3    1   92
# 8    9     2  200250            22       5         6      1    1    2   32
# 9   10     2  200250            22       5         6      1    2    1   34
#
#    ...             ingpc  pobreza  epobreza nnivins estrato           upm  \
# ...

# %%
df.to_csv('Ecuador2020.csv')
